# %% [markdown]
# # Continuos Regression with *KQM*
#
# ### Concept
#
# We will set `output_dim = 2` so that the model would predict a $2-\dim$ vector: $[cos^2\theta, sin^2\theta]$, and we will actually do the inference over $\theta$. Therefore, the range of the output variable must be within $[0, \pi/2]$.

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.decomposition import PCA
from sklearn import metrics
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.layers import Input, Dense, Dropout, Activation
from keras.models import Model
from keras import optimizers
from keras import losses
import concurrent.futures
from itertools import product
from keras.layers import Input, Dense, Reshape
import kqm
import itertools
print("Tensorflow version:",tf.__version__)
# Out:
# 2024-10-23 21:49:56.934285: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-23 21:49:57.069978: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-23 21:49:57.070017: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 21:49:57.092256: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-23 21:49:57.140155: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-23 21:49:57.704718: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Tensorflow version: 2.15.0

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# 2024-10-23 21:50:00.179921: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:50:00.258185: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:50:00.258326: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Check GPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Oct 23 21:50:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A2000 8GB Lap...    Off | 00000000:01:00.0 Off |                  N/A |
# | N/A   46C    P0               7W /  40W |      9MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2451      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Loading Dataset
#
# ## CCPP: Combined Cycle Power Plant
#
# https://archive.ics.uci.edu/dataset/294/combined+cycle+power+plant
#
# The dataset contains 9568 data points collected from a Combined Cycle Power Plant over 6 years (2006-2011), when the power plant was set to work with full load. Features consist of hourly average ambient variables Temperature (T), Ambient Pressure (AP), Relative Humidity (RH) and Exhaust Vacuum (V) to predict the net hourly electrical energy output (EP)  of the plant.
# A combined cycle power plant (CCPP) is composed of gas turbines (GT), steam turbines (ST) and heat recovery steam generators. In a CCPP, the electricity is generated by gas and steam turbines, which are combined in one cycle, and is transferred from one turbine to another. While the Vacuum is colected from and has effect on the Steam Turbine, he other three of the ambient variables effect the GT performance.
# For comparability with our baseline studies, and to allow 5x2 fold statistical tests be carried out, we provide the data shuffled five times. For each shuffling 2-fold CV is carried out and the resulting 10 measurements are used for statistical testing.
# We provide the data both in .ods and in .xlsx formats.
#
# Each shuffle is in a single sheet in the .ods file

# %%
#!pip install ucimlrepo
from ucimlrepo import fetch_ucirepo 

combined_cycle_power_plant = fetch_ucirepo(id=294) 
  
# data (as pandas dataframes) 
X = combined_cycle_power_plant.data.features 
y = combined_cycle_power_plant.data.targets

# %% [markdown]
# ## 70% - 30% Hold Out and MinMax Scaling for `y`

# %%
from sklearn.model_selection import train_test_split

# Split data into 70% training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Training set size: {X_train.shape}")
print(f"Test set size: {X_test.shape}")

X_train = np.asarray(X_train)
X_test = np.asarray(X_test)

scaler_x = StandardScaler()
scaler_x.fit(X_train)
X_train = scaler_x.transform(X_train)
X_test = scaler_x.transform(X_test)

scaler = MinMaxScaler(feature_range=(0.2, np.pi/2-0.2))
scaler.fit(y_train)
y_train = scaler.transform(y_train)
#y_test = scaler.transform(y_test))
y_train = np.asarray(y_train).reshape(-1)
y_test = np.asarray(y_test).reshape(-1)

print(f"Training features size: {X_train.shape}")
print(f"Training labels size: {y_train.shape}")
# Out:
# Training set size: (6697, 4)
# Test set size: (2871, 4)
# Training features size: (6697, 4)
# Training labels size: (6697,)

# %% [markdown]
# ## Defining KQM-Model

# %%
n_comp=32

# %%
class KQMModel:
    def __init__(self,
                 encoding_dim,
                 kernel_function,
                 num_hidden_layerss,
                 input_shape=(4,),
                 output_dim=2,
                 n_comp=n_comp,
                 sigma=0.1,
                 use_dense_layers=True):
        self.encoding_dim = encoding_dim
        self.kernel_function = kernel_function
        self.num_hidden_layerss = num_hidden_layerss
        self.input_shape = input_shape
        self.output_dim = output_dim
        self.n_comp = n_comp
        self.sigma = sigma
        self.use_dense_layers = use_dense_layers  # New parameter tio turn off the dense layer model
        self.encoder = None
        self.encoder_aux = None
        self.kqm_class_encoded = None
        self.kqm_class_out = None
        self.kqm_unit_encoded = None
        self.kqm_unit_out = None
        self.kernel_encoded = None  # almacenamos la instancia de kernel
        self.kernel_out = None  # almacenamos la instancia de kernel
        self.build_model()

    def build_model(self):
        inputs = Input(shape=self.input_shape)
        
        if self.use_dense_layers:
            encoded = Dense(self.encoding_dim, activation='relu')(inputs)
            encoded = Dropout(0.1)(encoded)
            if self.num_hidden_layerss == 2:
                encoded = Dense(self.encoding_dim, activation='relu')(encoded)
                encoded = Dropout(0.1)(encoded)
            out = Dense(self.encoding_dim)(encoded)
            encoded = Activation('tanh')(out)
        else:
            # Skip dense layers, directly output the input
            encoded = inputs
            out = inputs
            #self.encoding_dim=1
        
        self.encoder = Model(inputs, encoded)
        self.encoder_aux = Model(inputs, out)

        self.kqm_class_encoded, self.kqm_unit_encoded, self.kernel_encoded = self.build_kqm_class(inputs, encoded)
        self.kqm_class_out, self.kqm_unit_out, self.kernel_out = self.build_kqm_class(inputs, out)

    def build_kqm_class(self, inputs, tensor):
        if self.kernel_function == 'rbf':
          kernel = kqm.RBFKernelLayer(sigma=self.sigma, dim=self.encoding_dim)
        else:
          kernel = kqm.CosineKernelLayer()
        kqm_unit = kqm.KQMUnit(kernel=kernel,
                               dim_x=self.encoding_dim,
                               dim_y=self.output_dim,
                               n_comp=self.n_comp)

        rho_x = kqm.pure2dm(tensor)
        rho_y = kqm_unit(rho_x)
        probs = kqm.dm2discrete(rho_y)
        probs_0_sqrt = tf.sqrt(probs[:, 0])  # Assuming probs is a 2D array, take the first column
        theta = tf.acos(probs_0_sqrt)
        return Model(inputs, theta), kqm_unit, kernel

    def summary(self):
        print("Encoder:")
        self.encoder.summary()
        print("Encoder Aux:")
        self.encoder_aux.summary()
        print("KQM Class Encoded:")
        self.kqm_class_encoded.summary()
        print("KQM Class Out:")
        self.kqm_class_out.summary()

# %% [markdown]
# ## Training and Test

# %%
stoppping_a = EarlyStopping(
                        monitor="val_loss",
                        min_delta=0,
                        patience=50,
                        verbose=0,
                        mode="min",
                        baseline=None,
                        restore_best_weights=True,
                        start_from_epoch=0,
                    )

kernel = 'rbf'
learning_rate = 0.001
encoding_dim = 4
num_hidden_layer = 1

kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=False)
kqm_model.encoder.trainable = True

kqm_model.kqm_class_encoded.compile(
          optimizer=optimizers.Adam(learning_rate=learning_rate),
          loss=losses.mse)

np.random.seed(42)
indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
selected_samples = X_train[indices]
kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
#kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(X,verbose=0))

history = kqm_model.kqm_class_encoded.fit(X_train, y_train,
          validation_split = 0.2,
          epochs=200,
          batch_size=32,
          verbose=0,
          callbacks=[stoppping_a])

# Plotting the learning curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
print('MAE =',mean_absolute_error(y_test, y_pred))
print('MSE =',mean_squared_error(y_test, y_pred))
print('R^2 =',r2_score(y_test, y_pred))
# Out:
# 2024-10-23 21:59:15.949430: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:59:15.949620: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:59:15.949699: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:59:16.045890: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:59:16.046028: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:59:16.046103: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-23 21:59:16.046161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6348 MB memory:  -> device: 0, name: NVIDIA RTX A2000 8GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-23 21:59:16.888280: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-10-23 21:59:17.582282: I external/local_xla/xla/service/service.cc:168] XLA service 0x7474a4af8a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-23 21:59:17.582301: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A2000 8GB Laptop GPU, Compute Capability 8.6
# 2024-10-23 21:59:17.588540: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-23 21:59:17.604368: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729738757.660151    8382 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# MAE = 3.303500245246103
# MSE = 18.16717770917949
# R^2 = 0.9380297454326431

# %% [markdown]
# # Initializing weights `c_y`

# %%
stoppping_a = EarlyStopping(
                        monitor="val_loss",
                        min_delta=0,
                        patience=100,
                        verbose=0,
                        mode="min",
                        baseline=None,
                        restore_best_weights=True,
                        start_from_epoch=0,
                    )

kernel = 'rbf'
learning_rate = 0.001
encoding_dim = 4
num_hidden_layer = 1

kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=False)
kqm_model.encoder.trainable = True

kqm_model.kqm_class_encoded.compile(
          optimizer=optimizers.Adam(learning_rate=learning_rate),
          loss=losses.mse)

np.random.seed(42)
indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
selected_samples = X_train[indices]
selected_labels = y_train[indices]
cos_values = np.cos(selected_labels)
sin_values = np.sin(selected_labels)
kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
kqm_model.kqm_unit_encoded.c_y.assign(np.column_stack((cos_values, sin_values)))
print('ok')

history = kqm_model.kqm_class_encoded.fit(X_train, y_train,
          validation_split = 0.2,
          epochs=200,
          batch_size=32,
          verbose=0,
          callbacks=[stoppping_a])

# Plotting the learning curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
print('MAE =',mean_absolute_error(y_test, y_pred))
print('MSE =',mean_squared_error(y_test, y_pred))
print('R^2 =',r2_score(y_test, y_pred))
# Out:
# ok
# MAE = 3.2673518161647457
# MSE = 17.720458218351514
# R^2 = 0.9395535550749532

# %%
y_pred
# Out:
# array([455.16696, 438.70236, 434.44925, ..., 472.3231 , 476.56485,
#        440.64685], dtype=float32)

# %%
y_test
# Out:
# array([455.27, 436.31, 440.68, ..., 477.18, 481.95, 441.57])

# %% [markdown]
# # Hyper-parameter exploration
#
# We are going to explore:
# ```
# learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
# kernels = ['rbf', 'cos']
# ```

# %%
# Defining hyperparams to explore
learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
kernels = ['rbf', 'cos']

# Some fixed hyper-params
encoding_dim = 4
num_hidden_layer = 1
n_comp=32

# For saving:
best_model = None
best_hyperparameters = None

# %%
class KQMModel:
    def __init__(self,
                 encoding_dim,
                 kernel_function,
                 num_hidden_layerss,
                 input_shape=(4,),
                 output_dim=2,
                 n_comp=n_comp,
                 sigma=0.1,
                 use_dense_layers=True):
        self.encoding_dim = encoding_dim
        self.kernel_function = kernel_function
        self.num_hidden_layerss = num_hidden_layerss
        self.input_shape = input_shape
        self.output_dim = output_dim
        self.n_comp = n_comp
        self.sigma = sigma
        self.use_dense_layers = use_dense_layers  # New parameter tio turn off the dense layer model
        self.encoder = None
        self.encoder_aux = None
        self.kqm_class_encoded = None
        self.kqm_class_out = None
        self.kqm_unit_encoded = None
        self.kqm_unit_out = None
        self.kernel_encoded = None  # almacenamos la instancia de kernel
        self.kernel_out = None  # almacenamos la instancia de kernel
        self.build_model()

    def build_model(self):
        inputs = Input(shape=self.input_shape)
        
        if self.use_dense_layers:
            encoded = Dense(self.encoding_dim, activation='relu')(inputs)
            encoded = Dropout(0.1)(encoded)
            if self.num_hidden_layerss == 2:
                encoded = Dense(self.encoding_dim, activation='relu')(encoded)
                encoded = Dropout(0.1)(encoded)
            out = Dense(self.encoding_dim)(encoded)
            encoded = Activation('tanh')(out)
        else:
            # Skip dense layers, directly output the input
            encoded = inputs
            out = inputs
            #self.encoding_dim=1
        
        self.encoder = Model(inputs, encoded)
        self.encoder_aux = Model(inputs, out)

        self.kqm_class_encoded, self.kqm_unit_encoded, self.kernel_encoded = self.build_kqm_class(inputs, encoded)
        self.kqm_class_out, self.kqm_unit_out, self.kernel_out = self.build_kqm_class(inputs, out)

    def build_kqm_class(self, inputs, tensor):
        if self.kernel_function == 'rbf':
          kernel = kqm.RBFKernelLayer(sigma=self.sigma, dim=self.encoding_dim)
        else:
          kernel = kqm.CosineKernelLayer()
        kqm_unit = kqm.KQMUnit(kernel=kernel,
                               dim_x=self.encoding_dim,
                               dim_y=self.output_dim,
                               n_comp=self.n_comp)

        rho_x = kqm.pure2dm(tensor)
        rho_y = kqm_unit(rho_x)
        probs = kqm.dm2discrete(rho_y)
        probs_0_sqrt = tf.sqrt(probs[:, 0])  # Assuming probs is a 2D array, take the first column
        theta = tf.acos(probs_0_sqrt)
        return Model(inputs, theta), kqm_unit, kernel

    def summary(self):
        print("Encoder:")
        self.encoder.summary()
        print("Encoder Aux:")
        self.encoder_aux.summary()
        print("KQM Class Encoded:")
        self.kqm_class_encoded.summary()
        print("KQM Class Out:")
        self.kqm_class_out.summary()

# %%
best_MSE = 1000

for lr, kernel in itertools.product(learning_rates, kernels):
    print(f"Running experiment with learning_rate={lr} and kernel={kernel}")

    stoppping_a = EarlyStopping(
                            monitor="val_loss",
                            min_delta=0,
                            patience=50,
                            verbose=0,
                            mode="min",
                            baseline=None,
                            restore_best_weights=True,
                            start_from_epoch=0,
                        )
    
    kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=False)
    kqm_model.encoder.trainable = True
    
    kqm_model.kqm_class_encoded.compile(
              optimizer=optimizers.Adam(learning_rate=lr),
              loss=losses.mse)
    
    np.random.seed(42)
    indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
    selected_samples = X_train[indices]
    kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
    #kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(X,verbose=0))
    
    kqm_model.kqm_class_encoded.fit(X_train, y_train,
              validation_split = 0.2,
              epochs=200,
              batch_size=32,
              verbose=0,
              callbacks=[stoppping_a])
    
    y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
    print('MAE =',mean_absolute_error(y_test, y_pred))
    print('MSE =',mean_squared_error(y_test, y_pred))
    print('R^2 =',r2_score(y_test, y_pred))

    if mean_squared_error(y_test, y_pred) < best_MSE:
        best_MSE = mean_squared_error(y_test, y_pred)
        best_model = kqm_model
        best_hyperparameters = (lr, kernel)
        print("New best model")

print("Best hyper-parameters:", best_hyperparameters)
# Out:
# Running experiment with learning_rate=1e-05 and kernel=rbf
# MAE = 5.892457650402869
# MSE = 57.46664775899602
# R^2 = 0.803974902003727
# New best model
# Running experiment with learning_rate=1e-05 and kernel=cos
# MAE = 14.348257496673362
# MSE = 275.7755550177407
# R^2 = 0.059299049005922644
# Running experiment with learning_rate=5e-05 and kernel=rbf
# MAE = 3.372563278426779
# MSE = 19.500972553933064
# R^2 = 0.9334800235444577
# New best model
# Running experiment with learning_rate=5e-05 and kernel=cos
# MAE = 14.003987396782344
# MSE = 260.26547737993076
# R^2 = 0.11220564104574726
# Running experiment with learning_rate=0.0001 and kernel=rbf
# MAE = 3.3026905865803777
# MSE = 18.0699465736186
# R^2 = 0.9383614116011055
# New best model
# Running experiment with learning_rate=0.0001 and kernel=cos
# MAE = 13.6899423573865
# MSE = 251.1082669996688
# R^2 = 0.14344189950459096
# Running experiment with learning_rate=0.0005 and kernel=rbf
# MAE = 3.2690892194098855
# MSE = 17.745550116181377
# R^2 = 0.9394679638333753
# New best model
# Running experiment with learning_rate=0.0005 and kernel=cos
# MAE = 13.202931797262767
# MSE = 238.26773272409102
# R^2 = 0.18724238357407652
# Running experiment with learning_rate=0.001 and kernel=rbf
# MAE = 3.284298762816745
# MSE = 17.701638709900546
# R^2 = 0.9396177505019043
# New best model
# Running experiment with learning_rate=0.001 and kernel=cos
# MAE = 13.268239470999735
# MSE = 238.82029666867163
# R^2 = 0.18535752678131778
# Running experiment with learning_rate=0.005 and kernel=rbf
# MAE = 3.439614623045514
# MSE = 19.4563514099097
# R^2 = 0.933632231207006
# Running experiment with learning_rate=0.005 and kernel=cos
# MAE = 13.294294921279741
# MSE = 239.61876468311587
# R^2 = 0.1826338639806836
# Running experiment with learning_rate=0.01 and kernel=rbf
# MAE = 3.4409786952227015
# MSE = 19.4566319297595
# R^2 = 0.9336312743227402
# Running experiment with learning_rate=0.01 and kernel=cos
# MAE = 13.19434913350912
# MSE = 238.95259270058935
# R^2 = 0.1849062503691291
# Running experiment with learning_rate=0.1 and kernel=rbf
# MAE = 3.4515167893237324
# MSE = 19.83617956817889
# R^2 = 0.9323365953060098
# Running experiment with learning_rate=0.1 and kernel=cos
# MAE = 14.920116884769028
# MSE = 293.35844957533834
# R^2 = -0.0006781510417632752
# Best hyper-parameters: (0.001, 'rbf')

# %% [markdown]
# ```
# Running experiment with learning_rate=0.001 and kernel=rbf
# MAE = 3.284298762816745
# MSE = 17.701638709900546
# R^2 = 0.9396177505019043
# New best model
# ```

# %% [markdown]
# ## Adding an Encoder
#
# We are going to explore:
# ```
# learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
# kernels = ['rbf', 'cos']
# encoding_dim = [6, 8, 16]
# num_hidden_layer = [1,2]
# ```

# %%
# Defining hyperparams to explore
learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
kernels = ['rbf', 'cos']
encoding_dim = [4, 8, 16]
num_hidden_layers = [1,2]

# Some fixed hyper-params

n_comp=32

# For saving:
best_model = None
best_hyperparameters = None

# %%
class KQMModel:
    def __init__(self,
                 encoding_dim,
                 kernel_function,
                 num_hidden_layerss,
                 input_shape=(4,),
                 output_dim=2,
                 n_comp=n_comp,
                 sigma=0.1,
                 use_dense_layers=True):
        self.encoding_dim = encoding_dim
        self.kernel_function = kernel_function
        self.num_hidden_layerss = num_hidden_layerss
        self.input_shape = input_shape
        self.output_dim = output_dim
        self.n_comp = n_comp
        self.sigma = sigma
        self.use_dense_layers = use_dense_layers  # New parameter tio turn off the dense layer model
        self.encoder = None
        self.encoder_aux = None
        self.kqm_class_encoded = None
        self.kqm_class_out = None
        self.kqm_unit_encoded = None
        self.kqm_unit_out = None
        self.kernel_encoded = None  # almacenamos la instancia de kernel
        self.kernel_out = None  # almacenamos la instancia de kernel
        self.build_model()

    def build_model(self):
        inputs = Input(shape=self.input_shape)
        
        if self.use_dense_layers:
            encoded = Dense(self.encoding_dim, activation='relu')(inputs)
            encoded = Dropout(0.1)(encoded)
            if self.num_hidden_layerss == 2:
                encoded = Dense(self.encoding_dim, activation='relu')(encoded)
                encoded = Dropout(0.1)(encoded)
            out = Dense(self.encoding_dim)(encoded)
            encoded = Activation('tanh')(out)
        else:
            # Skip dense layers, directly output the input
            encoded = inputs
            out = inputs
            #self.encoding_dim=1
        
        self.encoder = Model(inputs, encoded)
        self.encoder_aux = Model(inputs, out)

        self.kqm_class_encoded, self.kqm_unit_encoded, self.kernel_encoded = self.build_kqm_class(inputs, encoded)
        self.kqm_class_out, self.kqm_unit_out, self.kernel_out = self.build_kqm_class(inputs, out)

    def build_kqm_class(self, inputs, tensor):
        if self.kernel_function == 'rbf':
          kernel = kqm.RBFKernelLayer(sigma=self.sigma, dim=self.encoding_dim)
        else:
          kernel = kqm.CosineKernelLayer()
        kqm_unit = kqm.KQMUnit(kernel=kernel,
                               dim_x=self.encoding_dim,
                               dim_y=self.output_dim,
                               n_comp=self.n_comp)

        rho_x = kqm.pure2dm(tensor)
        rho_y = kqm_unit(rho_x)
        probs = kqm.dm2discrete(rho_y)
        probs_0_sqrt = tf.sqrt(probs[:, 0])  # Assuming probs is a 2D array, take the first column
        theta = tf.acos(probs_0_sqrt)
        return Model(inputs, theta), kqm_unit, kernel

    def summary(self):
        print("Encoder:")
        self.encoder.summary()
        print("Encoder Aux:")
        self.encoder_aux.summary()
        print("KQM Class Encoded:")
        self.kqm_class_encoded.summary()
        print("KQM Class Out:")
        self.kqm_class_out.summary()

# %%
best_MSE = 1000

for lr, kernel, encoding_dim, num_hidden_layer in itertools.product(learning_rates, kernels, encoding_dim, num_hidden_layers):
    print(f"Running experiment with learning_rate={lr}, kernel={kernel}, encoding_dim={encoding_dim} and num_h_l={num_hidden_layer}")

    stoppping_a = EarlyStopping(
                            monitor="val_loss",
                            min_delta=0,
                            patience=50,
                            verbose=0,
                            mode="min",
                            baseline=None,
                            restore_best_weights=True,
                            start_from_epoch=0,
                        )
    
    kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=True)
    kqm_model.encoder.trainable = True
    
    kqm_model.kqm_class_encoded.compile(
              optimizer=optimizers.Adam(learning_rate=lr),
              loss=losses.mse)
    
    np.random.seed(42)
    indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
    selected_samples = X_train[indices]
    kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
    #kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(X,verbose=0))
    
    kqm_model.kqm_class_encoded.fit(X_train, y_train,
              validation_split = 0.2,
              epochs=200,
              batch_size=32,
              verbose=0,
              callbacks=[stoppping_a])
    
    y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
    print('MAE =',mean_absolute_error(y_test, y_pred))
    print('MSE =',mean_squared_error(y_test, y_pred))
    print('R^2 =',r2_score(y_test, y_pred))

    if mean_squared_error(y_test, y_pred) < best_MSE:
        best_MSE = mean_squared_error(y_test, y_pred)
        best_model = kqm_model
        best_hyperparameters = (lr, kernel, encoding_dim, num_hidden_layer)
        print("New best model")

print("Best hyper-parameters:", best_hyperparameters)
# Out:
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 5.0977043837996066
# MSE = 42.27714062121203
# R^2 = 0.8557879925756071
# New best model
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 6.255914756910429
# MSE = 58.58695237149807
# R^2 = 0.8001534189345842
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 4.80661812511565
# MSE = 36.98298969629447
# R^2 = 0.8738469275289091
# New best model
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 5.391827529487357
# MSE = 47.87116125855089
# R^2 = 0.8367061688327934
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 4.59381526276028
# MSE = 33.97295573959961
# R^2 = 0.8841144866147939
# New best model
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 4.16031957676169
# MSE = 27.865829980027414
# R^2 = 0.9049465687386079
# New best model
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 6.528235021874864
# MSE = 66.21806901730888
# R^2 = 0.7741228351672914
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 8.88666117073891
# MSE = 119.88906338468823
# R^2 = 0.59104513113024
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 5.45443367666087
# MSE = 46.81420248488952
# R^2 = 0.8403115722322383
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 6.284116341894157
# MSE = 59.213180580025245
# R^2 = 0.7980172851816745
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 4.238098835029988
# MSE = 29.263365227739975
# R^2 = 0.9001794212788327
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 4.479572476261129
# MSE = 32.52684117910888
# R^2 = 0.8890473434889736
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.8640484217341795
# MSE = 23.633605686838116
# R^2 = 0.9193831543785763
# New best model
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 4.466220567916503
# MSE = 32.343939354649834
# R^2 = 0.8896712418624031
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.6831818109536907
# MSE = 21.593307912510312
# R^2 = 0.9263428359808771
# New best model
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.7155123343313248
# MSE = 22.428485672654684
# R^2 = 0.9234939521732953
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.256412796982486
# MSE = 17.83574960026885
# R^2 = 0.9391602834066065
# New best model
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 3.443117273982415
# MSE = 19.076719525694298
# R^2 = 0.934927197595474
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 5.024745050773767
# MSE = 41.37620927854434
# R^2 = 0.8588611691331645
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 5.051289517872012
# MSE = 44.04887495055369
# R^2 = 0.849744410618485
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.2884428998361845
# MSE = 17.819668868993936
# R^2 = 0.9392151365613831
# New best model
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 4.5658108300475115
# MSE = 33.43764394221852
# R^2 = 0.8859404944233624
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.1886541758676468
# MSE = 17.22943495357493
# R^2 = 0.9412284897953487
# New best model
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 3.2946658768449577
# MSE = 17.86262498178578
# R^2 = 0.9390686085047114
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.5980037949368406
# MSE = 20.918365800220254
# R^2 = 0.9286451382529416
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 4.44520084414321
# MSE = 31.81256513491707
# R^2 = 0.8914838181576595
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.5267930364392845
# MSE = 19.91610339722937
# R^2 = 0.9320639662762539
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.6873156342860174
# MSE = 21.84670128068766
# R^2 = 0.9254784831472669
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.203962398517094
# MSE = 17.367263006343972
# R^2 = 0.9407583430475517
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 3.3164048277596825
# MSE = 17.934168917614617
# R^2 = 0.9388245642185248
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 4.947383011060905
# MSE = 41.942666986920344
# R^2 = 0.8569289191738344
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 5.607984020481621
# MSE = 53.49771902574132
# R^2 = 0.8175133573376677
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.359345551759513
# MSE = 18.49348538230513
# R^2 = 0.9369166738320576
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 3.907237689138829
# MSE = 25.902859699960576
# R^2 = 0.9116424776965764
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.193091171089259
# MSE = 17.159609968279508
# R^2 = 0.9414666705509501
# New best model
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 3.2361580420653193
# MSE = 17.460859248419947
# R^2 = 0.9404390759032079
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.5928205432048115
# MSE = 20.77829426807221
# R^2 = 0.9291229377572899
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 3.8325817539450266
# MSE = 24.051628905891366
# R^2 = 0.9179572308964326
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.325105932880801
# MSE = 17.945987486122124
# R^2 = 0.9387842497728384
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.379894286939302
# MSE = 18.614080356822164
# R^2 = 0.9365053110221595
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.1970915245021603
# MSE = 17.30226596217373
# R^2 = 0.9409800551614438
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 3.1717136380133493
# MSE = 17.00177529994592
# R^2 = 0.9420050620794947
# New best model
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 3.7544745751051734
# MSE = 22.563049048811525
# R^2 = 0.9230349415988752
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 4.1206223230418395
# MSE = 25.82837164360083
# R^2 = 0.9118965647038558
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.312852274257935
# MSE = 18.116280001478653
# R^2 = 0.9382033631488127
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 3.439716662516871
# MSE = 19.18638330041383
# R^2 = 0.9345531223183465
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.1599761909742625
# MSE = 16.79847449600795
# R^2 = 0.9426985436304248
# New best model
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 3.1508895889967827
# MSE = 16.649464405204377
# R^2 = 0.9432068335479907
# New best model
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.480792796295389
# MSE = 19.35460286724467
# R^2 = 0.9339793067512511
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 3.6527089528263503
# MSE = 21.708214947169576
# R^2 = 0.9259508753635811
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.269325169291242
# MSE = 17.745510784013387
# R^2 = 0.9394680979997551
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.5731314491901767
# MSE = 20.669983402750347
# R^2 = 0.9294923981106731
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.162622128987885
# MSE = 16.8737212538601
# R^2 = 0.9424418686083542
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 3.225033518101271
# MSE = 17.165081311638016
# R^2 = 0.9414480071929878
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 3.396841608178362
# MSE = 18.757845468956063
# R^2 = 0.9360149123075402
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 3.675736746420972
# MSE = 21.50180460463318
# R^2 = 0.9266549638949468
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.2668220799046503
# MSE = 17.696625777971402
# R^2 = 0.9396348501677276
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 3.6328173683562457
# MSE = 21.155014971726796
# R^2 = 0.9278379017280298
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.1301820663191724
# MSE = 16.5265861611992
# R^2 = 0.9436259848429077
# New best model
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 3.196737970865715
# MSE = 17.14952365551803
# R^2 = 0.941501076080498
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.330574046380426
# MSE = 18.223861594136658
# R^2 = 0.9378363904252284
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 3.840283925512533
# MSE = 23.46941706362205
# R^2 = 0.9199432199507109
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.299545909917467
# MSE = 17.771904221280803
# R^2 = 0.9393780670630542
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.305297097711353
# MSE = 17.877318369237386
# R^2 = 0.9390184877333176
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.0999949292561935
# MSE = 16.455257189576752
# R^2 = 0.9438692958623864
# New best model
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 3.321273728240786
# MSE = 18.123635946808818
# R^2 = 0.938178271204869
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 3.3537127968294196
# MSE = 18.580818278497958
# R^2 = 0.9366187716539751
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 3.406444184061792
# MSE = 18.722669916995056
# R^2 = 0.9361349000097835
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.285238772677611
# MSE = 17.777029895794044
# R^2 = 0.9393605828197941
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 3.291373194073684
# MSE = 17.984434345777146
# R^2 = 0.9386531032778639
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.150934469288793
# MSE = 16.821381218764014
# R^2 = 0.9426204062629581
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 3.1652189195633595
# MSE = 16.80186966417418
# R^2 = 0.9426869623359097
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.301121541298627
# MSE = 18.06669584020137
# R^2 = 0.9383725002127007
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 3.593217391197127
# MSE = 20.960531089136364
# R^2 = 0.9285013077840671
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.2904606349390995
# MSE = 17.793449346302413
# R^2 = 0.9393045742562105
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.334225245960412
# MSE = 18.099448310710123
# R^2 = 0.9382607779095654
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.1816943380634193
# MSE = 17.04215286124424
# R^2 = 0.941867329747455
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 3.267135049732916
# MSE = 17.49141382150189
# R^2 = 0.9403348508715383
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 3.3881597715435605
# MSE = 18.81036226723795
# R^2 = 0.935835771694139
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 3.3547015633843817
# MSE = 18.82918098560344
# R^2 = 0.9357715789622568
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.2894925327493683
# MSE = 17.811077089391684
# R^2 = 0.9392444440728558
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 3.3643942170390595
# MSE = 18.227961129630895
# R^2 = 0.9378224064557724
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.0919450877477628
# MSE = 16.560531229316588
# R^2 = 0.9435101944572896
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 3.2354087238052673
# MSE = 17.263639467269243
# R^2 = 0.9411118144121428
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=4 and num_h_l=1
# MAE = 3.581090124031261
# MSE = 20.88869691692297
# R^2 = 0.9287463420986954
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=4 and num_h_l=2
# MAE = 6.0840598719379955
# MSE = 57.13930986249714
# R^2 = 0.805091487810301
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 3.4161459574870467
# MSE = 19.306574982617523
# R^2 = 0.9341431351831804
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 3.482576224002552
# MSE = 19.89303379491906
# R^2 = 0.9321426592439136
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 14.876123876408888
# MSE = 293.1621458829075
# R^2 = -8.537412877984707e-06
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 14.876490640085526
# MSE = 293.16170327099394
# R^2 = -7.027614636445634e-06
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=4 and num_h_l=1
# MAE = 3.3978225351916254
# MSE = 18.909021345085577
# R^2 = 0.93549923465644
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=4 and num_h_l=2
# MAE = 4.409929194541726
# MSE = 33.30550053207121
# R^2 = 0.8863912502257946
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 3.4379558809573374
# MSE = 19.081912268981604
# R^2 = 0.9349094845732001
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 3.528102955487661
# MSE = 21.063286704100832
# R^2 = 0.9281507970047095
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.4030051100308034
# MSE = 19.120471399186897
# R^2 = 0.9347779551109485
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 4.203504690969502
# MSE = 29.395893840819163
# R^2 = 0.8997273515065517
# Best hyper-parameters: (0.005, 'rbf', 16, 1)

# %% [markdown]
# ```
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 3.0999949292561935
# MSE = 16.455257189576752
# R^2 = 0.9438692958623864
# New best model
# ```
#
# So, an encoder does improves the performance in this case.

# %%
y_test.max(), y_test.mean(), y_test.min()
# Out:
# (495.35, 454.2635597352839, 425.11)
