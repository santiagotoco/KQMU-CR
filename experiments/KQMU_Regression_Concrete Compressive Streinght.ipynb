# %% [markdown]
# # Continuos Regression with *KQM*
#
# ### Concept
#
# We will set `output_dim = 2` so that the model would predict a $2-\dim$ vector: $[cos^2\theta, sin^2\theta]$, and we will actually do the inference over $\theta$. Therefore, the range of the output variable must be within $[0, \pi/2]$.

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.decomposition import PCA
from sklearn import metrics
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.layers import Input, Dense, Dropout, Activation
from keras.models import Model
from keras import optimizers
from keras import losses
import concurrent.futures
from itertools import product
from keras.layers import Input, Dense, Reshape
import kqm
import itertools
print("Tensorflow version:",tf.__version__)
# Out:
# 2024-10-24 16:29:05.761152: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-24 16:29:05.894649: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 16:29:05.894709: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 16:29:05.915069: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-24 16:29:05.956712: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-24 16:29:06.512189: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Tensorflow version: 2.15.0

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# 2024-10-24 16:29:07.172302: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:07.245117: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:07.245267: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Check GPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Oct 24 16:29:08 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A2000 8GB Lap...    Off | 00000000:01:00.0 Off |                  N/A |
# | N/A   50C    P8               5W /  40W |      9MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2479      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Loading Dataset
#
# ## CON: Concrete Compressive Streinght
# https://archive.ics.uci.edu/dataset/165/concrete+compressive+strength

# %%
#!pip install ucimlrepo
from ucimlrepo import fetch_ucirepo 

concrete_compressive_strength = fetch_ucirepo(id=165) 
  
# data (as pandas dataframes) 
X = concrete_compressive_strength.data.features 
y = concrete_compressive_strength.data.targets

# %% [markdown]
# ## 70% - 30% Hold Out and MinMax Scaling for `y`

# %%
from sklearn.model_selection import train_test_split

# Split data into 70% training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Training set size: {X_train.shape}")
print(f"Test set size: {X_test.shape}")

X_train = np.asarray(X_train)
X_test = np.asarray(X_test)

scaler_x = StandardScaler()
scaler_x.fit(X_train)
X_train = scaler_x.transform(X_train)
X_test = scaler_x.transform(X_test)

scaler = MinMaxScaler(feature_range=(0.2, np.pi/2-0.2))
scaler.fit(y_train)
y_train = scaler.transform(y_train)
#y_test = scaler.transform(y_test))
y_train = np.asarray(y_train).reshape(-1)
y_test = np.asarray(y_test).reshape(-1)

print(f"Training features size: {X_train.shape}")
print(f"Training labels size: {y_train.shape}")
# Out:
# Training set size: (721, 8)
# Test set size: (309, 8)
# Training features size: (721, 8)
# Training labels size: (721,)

# %% [markdown]
# ## Defining KQM-Model

# %%
n_comp=32

# %%
class KQMModel:
    def __init__(self,
                 encoding_dim,
                 kernel_function,
                 num_hidden_layerss,
                 input_shape=(8,),
                 output_dim=2,
                 n_comp=n_comp,
                 sigma=0.1,
                 use_dense_layers=True):
        self.encoding_dim = encoding_dim
        self.kernel_function = kernel_function
        self.num_hidden_layerss = num_hidden_layerss
        self.input_shape = input_shape
        self.output_dim = output_dim
        self.n_comp = n_comp
        self.sigma = sigma
        self.use_dense_layers = use_dense_layers  # New parameter tio turn off the dense layer model
        self.encoder = None
        self.encoder_aux = None
        self.kqm_class_encoded = None
        self.kqm_class_out = None
        self.kqm_unit_encoded = None
        self.kqm_unit_out = None
        self.kernel_encoded = None  # almacenamos la instancia de kernel
        self.kernel_out = None  # almacenamos la instancia de kernel
        self.build_model()

    def build_model(self):
        inputs = Input(shape=self.input_shape)
        
        if self.use_dense_layers:
            encoded = Dense(self.encoding_dim, activation='relu')(inputs)
            encoded = Dropout(0.1)(encoded)
            if self.num_hidden_layerss == 2:
                encoded = Dense(self.encoding_dim, activation='relu')(encoded)
                encoded = Dropout(0.1)(encoded)
            out = Dense(self.encoding_dim)(encoded)
            encoded = Activation('tanh')(out)
        else:
            # Skip dense layers, directly output the input
            encoded = inputs
            out = inputs
            #self.encoding_dim=1
        
        self.encoder = Model(inputs, encoded)
        self.encoder_aux = Model(inputs, out)

        self.kqm_class_encoded, self.kqm_unit_encoded, self.kernel_encoded = self.build_kqm_class(inputs, encoded)
        self.kqm_class_out, self.kqm_unit_out, self.kernel_out = self.build_kqm_class(inputs, out)

    def build_kqm_class(self, inputs, tensor):
        if self.kernel_function == 'rbf':
          kernel = kqm.RBFKernelLayer(sigma=self.sigma, dim=self.encoding_dim)
        else:
          kernel = kqm.CosineKernelLayer()
        kqm_unit = kqm.KQMUnit(kernel=kernel,
                               dim_x=self.encoding_dim,
                               dim_y=self.output_dim,
                               n_comp=self.n_comp)

        rho_x = kqm.pure2dm(tensor)
        rho_y = kqm_unit(rho_x)
        probs = kqm.dm2discrete(rho_y)
        probs_0_sqrt = tf.sqrt(probs[:, 0])  # Assuming probs is a 2D array, take the first column
        theta = tf.acos(probs_0_sqrt)
        return Model(inputs, theta), kqm_unit, kernel

    def summary(self):
        print("Encoder:")
        self.encoder.summary()
        print("Encoder Aux:")
        self.encoder_aux.summary()
        print("KQM Class Encoded:")
        self.kqm_class_encoded.summary()
        print("KQM Class Out:")
        self.kqm_class_out.summary()

# %% [markdown]
# ## Training and Test

# %%
stoppping_a = EarlyStopping(
                        monitor="val_loss",
                        min_delta=0,
                        patience=50,
                        verbose=0,
                        mode="min",
                        baseline=None,
                        restore_best_weights=True,
                        start_from_epoch=0,
                    )

kernel = 'rbf'
learning_rate = 0.001
encoding_dim = 8
num_hidden_layer = 1

kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=False)
kqm_model.encoder.trainable = True

kqm_model.kqm_class_encoded.compile(
          optimizer=optimizers.Adam(learning_rate=learning_rate),
          loss=losses.mse)

np.random.seed(42)
indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
selected_samples = X_train[indices]
kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
#kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(X,verbose=0))

history = kqm_model.kqm_class_encoded.fit(X_train, y_train,
          validation_split = 0.2,
          epochs=200,
          batch_size=32,
          verbose=0,
          callbacks=[stoppping_a])

# Plotting the learning curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
print('MAE =',mean_absolute_error(y_test, y_pred))
print('MSE =',mean_squared_error(y_test, y_pred))
print('R^2 =',r2_score(y_test, y_pred))
# Out:
# 2024-10-24 16:29:37.492797: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:37.492971: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:37.493038: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:37.580510: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:37.580654: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:37.580734: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 16:29:37.580793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6348 MB memory:  -> device: 0, name: NVIDIA RTX A2000 8GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-24 16:29:38.405692: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-10-24 16:29:39.102633: I external/local_xla/xla/service/service.cc:168] XLA service 0x702f105a5e90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-24 16:29:39.102655: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A2000 8GB Laptop GPU, Compute Capability 8.6
# 2024-10-24 16:29:39.108791: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-24 16:29:39.124683: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729805379.186214   16385 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# MAE = 10.275583696828305
# MSE = 180.3865844408387
# R^2 = 0.3333195100320624

# %% [markdown]
# # Initializing weights `c_y`

# %%
stoppping_a = EarlyStopping(
                        monitor="val_loss",
                        min_delta=0,
                        patience=100,
                        verbose=0,
                        mode="min",
                        baseline=None,
                        restore_best_weights=True,
                        start_from_epoch=0,
                    )

kernel = 'rbf'
learning_rate = 0.001
encoding_dim = 8
num_hidden_layer = 1

kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=False)
kqm_model.encoder.trainable = True

kqm_model.kqm_class_encoded.compile(
          optimizer=optimizers.Adam(learning_rate=learning_rate),
          loss=losses.mse)

np.random.seed(42)
indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
selected_samples = X_train[indices]
selected_labels = y_train[indices]
cos_values = np.cos(selected_labels)
sin_values = np.sin(selected_labels)
kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
kqm_model.kqm_unit_encoded.c_y.assign(np.column_stack((cos_values, sin_values)))
print('ok')

history = kqm_model.kqm_class_encoded.fit(X_train, y_train,
          validation_split = 0.2,
          epochs=200,
          batch_size=32,
          verbose=0,
          callbacks=[stoppping_a])

# Plotting the learning curves
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
print('MAE =',mean_absolute_error(y_test, y_pred))
print('MSE =',mean_squared_error(y_test, y_pred))
print('R^2 =',r2_score(y_test, y_pred))
# Out:
# ok
# MAE = 13.162420406279825
# MSE = 266.426074601889
# R^2 = 0.015331065187522586

# %%
y_pred
# Out:
# array([36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 25.39734 ,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 31.060886, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        30.354338, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 27.655731, 36.648098,
#        12.719499, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 35.63315 , 36.648098, 36.648098, 40.94763 , 36.648098,
#        36.648098, 41.21208 , 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 25.198414, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 52.516617, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 43.01785 , 36.648098, 36.648098, 36.648098, 43.588135,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 48.028667, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 25.10984 , 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        26.211672, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 21.224777, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 31.922455, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 29.435577,
#        36.648098, 41.272957, 36.648098, 36.648098, 36.648098, 16.74504 ,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098, 36.648098, 36.648098, 36.648098,
#        36.648098, 36.648098, 36.648098], dtype=float32)

# %%
y_test
# Out:
# array([52.91, 55.9 , 74.5 , 35.3 , 10.54, 44.28, 23.69, 45.37, 37.4 ,
#        48.85, 25.1 , 10.73, 40.2 , 49.8 , 33.01, 21.92, 40.06, 19.35,
#        37.17, 33.09, 31.38, 37.96, 48.72,  6.9 , 38.6 , 30.85, 11.17,
#        41.05, 52.96, 13.22, 52.3 , 39.6 , 51.86, 66.42, 14.94, 33.02,
#        31.64, 39.42, 13.66, 51.96, 15.58,  6.28, 38.07, 50.24, 10.03,
#        63.4 , 55.55, 36.15, 21.75,  4.83, 57.21, 47.78, 29.41, 12.37,
#        64.02, 34.4 , 25.37, 13.71, 31.72, 19.77, 39.42, 13.52, 35.34,
#        46.8 , 33.  , 18.03, 33.4 , 12.18, 27.66, 24.43, 11.65, 24.05,
#         9.31, 25.1 , 26.14, 11.58, 55.26, 60.95, 61.86, 14.59, 44.21,
#        34.9 , 41.68, 39.59, 41.05, 35.3 , 44.61, 33.72, 21.5 , 20.08,
#        31.65, 75.5 , 15.04, 56.61, 53.52, 50.66, 31.35, 45.71, 19.11,
#        32.92, 25.45, 41.94, 36.25, 24.  , 70.7 , 10.34, 56.81, 30.12,
#        44.64, 44.52, 44.7 , 51.04, 30.28, 37.34, 38.61, 61.07, 18.13,
#        33.76, 61.99, 53.52, 19.77, 26.94, 51.43, 29.98, 21.91, 43.5 ,
#        59.76, 49.2 , 42.14, 32.4 , 11.47, 41.89, 12.25, 71.7 ,  8.2 ,
#        40.27, 31.74, 39.61, 22.5 , 37.36, 33.69, 31.18, 23.08, 31.25,
#        46.23, 43.57, 26.86, 13.2 ,  6.88, 14.8 , 48.28, 15.09, 41.67,
#        29.75, 48.15, 41.16, 23.84, 71.62, 55.9 , 52.42, 14.64, 56.7 ,
#        35.23, 53.3 , 33.4 , 66.78, 41.54, 29.93, 52.01, 21.02, 51.33,
#        16.89, 24.28, 38.63, 36.35,  8.  , 30.44, 55.83, 52.43, 36.45,
#        33.05, 26.92, 44.52, 32.72, 52.5 , 54.38, 22.44, 30.22, 24.1 ,
#        17.24, 34.77, 37.68, 40.39, 40.29, 29.79, 32.9 , 60.32, 15.09,
#        19.99, 25.73, 47.71, 56.14, 18.75, 38.  , 74.36, 35.17, 27.68,
#        62.05, 23.8 , 33.4 ,  7.4 , 27.77, 18.29, 48.59, 39.7 ,  4.57,
#        13.29, 36.97, 22.53, 71.3 , 25.61, 76.24, 62.94, 17.54, 41.05,
#        21.86, 47.13, 16.5 , 22.72, 29.72, 19.93,  9.62, 39.05, 42.13,
#        39.32, 34.49, 28.1 , 38.6 , 53.77,  7.32, 32.82, 43.38, 55.16,
#        35.23, 66.7 , 30.88, 76.8 , 17.96, 55.06, 64.3 , 33.8 , 45.94,
#        37.26, 24.85, 40.15, 13.54, 32.88, 17.57, 21.54, 17.84, 23.4 ,
#        55.55, 17.6 , 31.42, 13.82, 65.91, 81.75, 28.8 , 42.8 , 42.13,
#        13.33, 12.47, 27.42, 32.04, 39.4 , 33.4 , 28.3 , 15.36, 41.1 ,
#        23.84, 43.25, 34.57, 10.22, 39.09, 24.66, 22.95, 47.03, 18.13,
#        33.4 , 45.7 , 31.12, 20.73, 36.56, 12.46, 32.66, 38.5 , 25.18,
#        17.95, 19.2 , 26.2 , 15.52, 11.41, 60.29, 69.84, 24.92, 36.3 ,
#        32.33, 39.29, 66.82])

# %% [markdown]
# # Hyper-parameter exploration
#
# We are going to explore:
# ```
# learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
# kernels = ['rbf', 'cos']
# ```

# %%
# Defining hyperparams to explore
learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
kernels = ['rbf', 'cos']

# Some fixed hyper-params
encoding_dim = 8
num_hidden_layer = 1
n_comp=32

# For saving:
best_model = None
best_hyperparameters = None

# %%
class KQMModel:
    def __init__(self,
                 encoding_dim,
                 kernel_function,
                 num_hidden_layerss,
                 input_shape=(8,),
                 output_dim=2,
                 n_comp=n_comp,
                 sigma=0.1,
                 use_dense_layers=True):
        self.encoding_dim = encoding_dim
        self.kernel_function = kernel_function
        self.num_hidden_layerss = num_hidden_layerss
        self.input_shape = input_shape
        self.output_dim = output_dim
        self.n_comp = n_comp
        self.sigma = sigma
        self.use_dense_layers = use_dense_layers  # New parameter tio turn off the dense layer model
        self.encoder = None
        self.encoder_aux = None
        self.kqm_class_encoded = None
        self.kqm_class_out = None
        self.kqm_unit_encoded = None
        self.kqm_unit_out = None
        self.kernel_encoded = None  # almacenamos la instancia de kernel
        self.kernel_out = None  # almacenamos la instancia de kernel
        self.build_model()

    def build_model(self):
        inputs = Input(shape=self.input_shape)
        
        if self.use_dense_layers:
            encoded = Dense(self.encoding_dim, activation='relu')(inputs)
            encoded = Dropout(0.1)(encoded)
            if self.num_hidden_layerss == 2:
                encoded = Dense(self.encoding_dim, activation='relu')(encoded)
                encoded = Dropout(0.1)(encoded)
            out = Dense(self.encoding_dim)(encoded)
            encoded = Activation('tanh')(out)
        else:
            # Skip dense layers, directly output the input
            encoded = inputs
            out = inputs
            #self.encoding_dim=1
        
        self.encoder = Model(inputs, encoded)
        self.encoder_aux = Model(inputs, out)

        self.kqm_class_encoded, self.kqm_unit_encoded, self.kernel_encoded = self.build_kqm_class(inputs, encoded)
        self.kqm_class_out, self.kqm_unit_out, self.kernel_out = self.build_kqm_class(inputs, out)

    def build_kqm_class(self, inputs, tensor):
        if self.kernel_function == 'rbf':
          kernel = kqm.RBFKernelLayer(sigma=self.sigma, dim=self.encoding_dim)
        else:
          kernel = kqm.CosineKernelLayer()
        kqm_unit = kqm.KQMUnit(kernel=kernel,
                               dim_x=self.encoding_dim,
                               dim_y=self.output_dim,
                               n_comp=self.n_comp)

        rho_x = kqm.pure2dm(tensor)
        rho_y = kqm_unit(rho_x)
        probs = kqm.dm2discrete(rho_y)
        probs_0_sqrt = tf.sqrt(probs[:, 0])  # Assuming probs is a 2D array, take the first column
        theta = tf.acos(probs_0_sqrt)
        return Model(inputs, theta), kqm_unit, kernel

    def summary(self):
        print("Encoder:")
        self.encoder.summary()
        print("Encoder Aux:")
        self.encoder_aux.summary()
        print("KQM Class Encoded:")
        self.kqm_class_encoded.summary()
        print("KQM Class Out:")
        self.kqm_class_out.summary()

# %%
best_MSE = 1000

for lr, kernel in itertools.product(learning_rates, kernels):
    print(f"Running experiment with learning_rate={lr} and kernel={kernel}")

    stoppping_a = EarlyStopping(
                            monitor="val_loss",
                            min_delta=0,
                            patience=50,
                            verbose=0,
                            mode="min",
                            baseline=None,
                            restore_best_weights=True,
                            start_from_epoch=0,
                        )
    
    kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=False)
    kqm_model.encoder.trainable = True
    
    kqm_model.kqm_class_encoded.compile(
              optimizer=optimizers.Adam(learning_rate=lr),
              loss=losses.mse)
    
    np.random.seed(42)
    indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
    selected_samples = X_train[indices]
    kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
    #kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(X,verbose=0))
    
    kqm_model.kqm_class_encoded.fit(X_train, y_train,
              validation_split = 0.2,
              epochs=200,
              batch_size=32,
              verbose=0,
              callbacks=[stoppping_a])
    
    y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
    print('MAE =',mean_absolute_error(y_test, y_pred))
    print('MSE =',mean_squared_error(y_test, y_pred))
    print('R^2 =',r2_score(y_test, y_pred))

    if mean_squared_error(y_test, y_pred) < best_MSE:
        best_MSE = mean_squared_error(y_test, y_pred)
        best_model = kqm_model
        best_hyperparameters = (lr, kernel)
        print("New best model")

print("Best hyper-parameters:", best_hyperparameters)
# Out:
# Running experiment with learning_rate=1e-05 and kernel=rbf
# MAE = 14.136742047553692
# MSE = 297.05364271236584
# R^2 = -0.09786361709837577
# New best model
# Running experiment with learning_rate=1e-05 and kernel=cos
# MAE = 13.913206879452208
# MSE = 287.9964423974711
# R^2 = -0.06438962698769668
# New best model
# Running experiment with learning_rate=5e-05 and kernel=rbf
# MAE = 13.340968443244021
# MSE = 271.586172958475
# R^2 = -0.0037398480476007467
# New best model
# Running experiment with learning_rate=5e-05 and kernel=cos
# MAE = 12.889336499704898
# MSE = 251.42166859755102
# R^2 = 0.07078499363601332
# New best model
# Running experiment with learning_rate=0.0001 and kernel=rbf
# MAE = 12.718162146509657
# MSE = 250.0624288826016
# R^2 = 0.07580853018090283
# New best model
# Running experiment with learning_rate=0.0001 and kernel=cos
# MAE = 12.693297123091119
# MSE = 245.50382952852866
# R^2 = 0.09265639755619337
# New best model
# Running experiment with learning_rate=0.0005 and kernel=rbf
# MAE = 10.82385506281189
# MSE = 191.12951326540374
# R^2 = 0.2936153320597772
# New best model
# Running experiment with learning_rate=0.0005 and kernel=cos
# MAE = 11.389106089397542
# MSE = 205.85876333077974
# R^2 = 0.2391783367539223
# Running experiment with learning_rate=0.001 and kernel=rbf
# MAE = 9.422832749622923
# MSE = 163.30708243289357
# R^2 = 0.39644266745732915
# New best model
# Running experiment with learning_rate=0.001 and kernel=cos
# MAE = 10.96507571124722
# MSE = 199.70878348943808
# R^2 = 0.26190769651550305
# Running experiment with learning_rate=0.005 and kernel=rbf
# MAE = 4.515519598680021
# MSE = 43.129255857126935
# R^2 = 0.8406010429438993
# New best model
# Running experiment with learning_rate=0.005 and kernel=cos
# MAE = 10.389112043041242
# MSE = 174.9145539492195
# R^2 = 0.35354327545553066
# Running experiment with learning_rate=0.01 and kernel=rbf
# MAE = 4.783419865790308
# MSE = 53.770301989942695
# R^2 = 0.8012734074016691
# Running experiment with learning_rate=0.01 and kernel=cos
# MAE = 10.272220625152094
# MSE = 172.271220794077
# R^2 = 0.36331261971403817
# Running experiment with learning_rate=0.1 and kernel=rbf
# MAE = 4.351878116015091
# MSE = 36.0206365174846
# R^2 = 0.8668733837559325
# New best model
# Running experiment with learning_rate=0.1 and kernel=cos
# MAE = 10.033618910829613
# MSE = 170.78905105645958
# R^2 = 0.3687904863189937
# Best hyper-parameters: (0.1, 'rbf')

# %% [markdown]
# ```
# Running experiment with learning_rate=0.1 and kernel=rbf
# MAE = 4.351878116015091
# MSE = 36.0206365174846
# R^2 = 0.8668733837559325
# New best model
# ```

# %% [markdown]
# ## Adding an Encoder
#
# We are going to explore:
# ```
# learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
# kernels = ['rbf', 'cos']
# encoding_dim = [6, 8, 16]
# num_hidden_layer = [1,2]
# ```

# %%
# Defining hyperparams to explore
learning_rates = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 1e-1]
kernels = ['rbf', 'cos']
encoding_dim = [8, 16, 32]
num_hidden_layers = [1,2]

# Some fixed hyper-params

n_comp=32

# For saving:
best_model = None
best_hyperparameters = None

# %%
class KQMModel:
    def __init__(self,
                 encoding_dim,
                 kernel_function,
                 num_hidden_layerss,
                 input_shape=(8,),
                 output_dim=2,
                 n_comp=n_comp,
                 sigma=0.1,
                 use_dense_layers=True):
        self.encoding_dim = encoding_dim
        self.kernel_function = kernel_function
        self.num_hidden_layerss = num_hidden_layerss
        self.input_shape = input_shape
        self.output_dim = output_dim
        self.n_comp = n_comp
        self.sigma = sigma
        self.use_dense_layers = use_dense_layers  # New parameter tio turn off the dense layer model
        self.encoder = None
        self.encoder_aux = None
        self.kqm_class_encoded = None
        self.kqm_class_out = None
        self.kqm_unit_encoded = None
        self.kqm_unit_out = None
        self.kernel_encoded = None  # almacenamos la instancia de kernel
        self.kernel_out = None  # almacenamos la instancia de kernel
        self.build_model()

    def build_model(self):
        inputs = Input(shape=self.input_shape)
        
        if self.use_dense_layers:
            encoded = Dense(self.encoding_dim, activation='relu')(inputs)
            encoded = Dropout(0.1)(encoded)
            if self.num_hidden_layerss == 2:
                encoded = Dense(self.encoding_dim, activation='relu')(encoded)
                encoded = Dropout(0.1)(encoded)
            out = Dense(self.encoding_dim)(encoded)
            encoded = Activation('tanh')(out)
        else:
            # Skip dense layers, directly output the input
            encoded = inputs
            out = inputs
            #self.encoding_dim=1
        
        self.encoder = Model(inputs, encoded)
        self.encoder_aux = Model(inputs, out)

        self.kqm_class_encoded, self.kqm_unit_encoded, self.kernel_encoded = self.build_kqm_class(inputs, encoded)
        self.kqm_class_out, self.kqm_unit_out, self.kernel_out = self.build_kqm_class(inputs, out)

    def build_kqm_class(self, inputs, tensor):
        if self.kernel_function == 'rbf':
          kernel = kqm.RBFKernelLayer(sigma=self.sigma, dim=self.encoding_dim)
        else:
          kernel = kqm.CosineKernelLayer()
        kqm_unit = kqm.KQMUnit(kernel=kernel,
                               dim_x=self.encoding_dim,
                               dim_y=self.output_dim,
                               n_comp=self.n_comp)

        rho_x = kqm.pure2dm(tensor)
        rho_y = kqm_unit(rho_x)
        probs = kqm.dm2discrete(rho_y)
        probs_0_sqrt = tf.sqrt(probs[:, 0])  # Assuming probs is a 2D array, take the first column
        theta = tf.acos(probs_0_sqrt)
        return Model(inputs, theta), kqm_unit, kernel

    def summary(self):
        print("Encoder:")
        self.encoder.summary()
        print("Encoder Aux:")
        self.encoder_aux.summary()
        print("KQM Class Encoded:")
        self.kqm_class_encoded.summary()
        print("KQM Class Out:")
        self.kqm_class_out.summary()

# %%
best_MSE = 1000

for lr, kernel, encoding_dim, num_hidden_layer in itertools.product(learning_rates, kernels, encoding_dim, num_hidden_layers):
    print(f"Running experiment with learning_rate={lr}, kernel={kernel}, encoding_dim={encoding_dim} and num_h_l={num_hidden_layer}")

    stoppping_a = EarlyStopping(
                            monitor="val_loss",
                            min_delta=0,
                            patience=50,
                            verbose=0,
                            mode="min",
                            baseline=None,
                            restore_best_weights=True,
                            start_from_epoch=0,
                        )
    
    kqm_model = KQMModel(encoding_dim = encoding_dim, kernel_function = kernel, num_hidden_layerss = num_hidden_layer, use_dense_layers=True)
    kqm_model.encoder.trainable = True
    
    kqm_model.kqm_class_encoded.compile(
              optimizer=optimizers.Adam(learning_rate=lr),
              loss=losses.mse)
    
    np.random.seed(42)
    indices = np.random.choice(X_train.shape[0], size=n_comp, replace=False)
    selected_samples = X_train[indices]
    kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(selected_samples,verbose=0))
    #kqm_model.kqm_unit_encoded.c_x.assign(kqm_model.encoder.predict(X,verbose=0))
    
    kqm_model.kqm_class_encoded.fit(X_train, y_train,
              validation_split = 0.2,
              epochs=200,
              batch_size=32,
              verbose=0,
              callbacks=[stoppping_a])
    
    y_pred = scaler.inverse_transform(kqm_model.kqm_class_encoded.predict(X_test, verbose = 0).reshape(-1, 1)).reshape(-1)
    print('MAE =',mean_absolute_error(y_test, y_pred))
    print('MSE =',mean_squared_error(y_test, y_pred))
    print('R^2 =',r2_score(y_test, y_pred))

    if mean_squared_error(y_test, y_pred) < best_MSE:
        best_MSE = mean_squared_error(y_test, y_pred)
        best_model = kqm_model
        best_hyperparameters = (lr, kernel, encoding_dim, num_hidden_layer)
        print("New best model")

print("Best hyper-parameters:", best_hyperparameters)
# Out:
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 13.947867545217372
# MSE = 284.9927100819408
# R^2 = -0.053288304025916
# New best model
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 13.930765603074748
# MSE = 285.8292133770099
# R^2 = -0.056379888848286264
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 14.169450653471223
# MSE = 296.6555425001274
# R^2 = -0.09639230122766285
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 14.182075882204911
# MSE = 297.1847020303288
# R^2 = -0.09834799175730757
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 14.044038873073736
# MSE = 294.0498273694875
# R^2 = -0.08676198728055429
# Running experiment with learning_rate=1e-05, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 14.028435465000978
# MSE = 293.6152316125146
# R^2 = -0.08515578960740267
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 13.375748248053986
# MSE = 262.8479221609193
# R^2 = 0.028555354731670923
# New best model
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 13.933823049600845
# MSE = 289.9675226804099
# R^2 = -0.0716744301944825
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 13.552147689868717
# MSE = 270.98999726957663
# R^2 = -0.0015364763189671393
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 13.435060710721803
# MSE = 268.66634249543876
# R^2 = 0.007051386842478968
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 13.254347033948187
# MSE = 257.6387992561538
# R^2 = 0.04780745499853567
# New best model
# Running experiment with learning_rate=1e-05, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 13.145388923324042
# MSE = 254.08127252112197
# R^2 = 0.060955515172394836
# New best model
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 10.722608569493957
# MSE = 174.92852099413923
# R^2 = 0.353491655450754
# New best model
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 11.638679633526355
# MSE = 198.25418297798655
# R^2 = 0.267283671589748
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 13.325424340504272
# MSE = 271.158565863187
# R^2 = -0.002159479370606121
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 12.463795278110936
# MSE = 237.9476663861114
# R^2 = 0.12058278998542948
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 13.440868273985037
# MSE = 274.49424655792467
# R^2 = -0.014487631416046254
# Running experiment with learning_rate=5e-05, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 13.224433877198056
# MSE = 268.30655623859633
# R^2 = 0.008381100350492776
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 11.588358199233761
# MSE = 202.468683889513
# R^2 = 0.2517075380242928
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 9.918776410544188
# MSE = 147.36320257007824
# R^2 = 0.45536874376106773
# New best model
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 9.861329388170951
# MSE = 138.91416254424695
# R^2 = 0.486595068942846
# New best model
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 8.9033073509241
# MSE = 120.6465269292775
# R^2 = 0.5541093816069222
# New best model
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 8.4353700683495
# MSE = 107.87535586817475
# R^2 = 0.601309624390347
# New best model
# Running experiment with learning_rate=5e-05, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 9.222406098202207
# MSE = 122.8125796911624
# R^2 = 0.5461039907345016
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 10.953120433967861
# MSE = 198.32321711652992
# R^2 = 0.26702853225413015
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 11.094887224956622
# MSE = 185.79425120301957
# R^2 = 0.31333362284555455
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 10.82044498011518
# MSE = 184.21006064297865
# R^2 = 0.31918854238984606
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 8.870664039290837
# MSE = 122.12263368584105
# R^2 = 0.5486539228278714
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 13.426894647295807
# MSE = 274.13248870191524
# R^2 = -0.013150631187111905
# Running experiment with learning_rate=0.0001, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 11.379814443742573
# MSE = 190.86817733111675
# R^2 = 0.29458118863529115
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 8.64715377313805
# MSE = 109.41838358766466
# R^2 = 0.5956068362409266
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 10.296836727105298
# MSE = 159.88609421865232
# R^2 = 0.40908610269900525
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 7.356340761153828
# MSE = 80.46866980795828
# R^2 = 0.7026004323939492
# New best model
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 8.4383134699948
# MSE = 109.89336118233747
# R^2 = 0.5938513936368003
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 6.4854286475320455
# MSE = 65.23056657581152
# R^2 = 0.7589180690989195
# New best model
# Running experiment with learning_rate=0.0001, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 6.298832959418929
# MSE = 62.50417280213618
# R^2 = 0.7689943923605063
# New best model
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 9.903830150616592
# MSE = 145.11501240758997
# R^2 = 0.4636777015680734
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 5.629665190070193
# MSE = 49.86470448855904
# R^2 = 0.8157078824703734
# New best model
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 7.518666815402824
# MSE = 89.05722989731058
# R^2 = 0.6708584629662484
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 5.728883813037069
# MSE = 48.673064624516904
# R^2 = 0.8201119962845329
# New best model
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 13.427866296366966
# MSE = 274.15291436726375
# R^2 = -0.013226121238795407
# Running experiment with learning_rate=0.0005, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 5.3432747361266495
# MSE = 46.6512484138412
# R^2 = 0.827584311513166
# New best model
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 6.228565781972941
# MSE = 64.73815980323072
# R^2 = 0.760737927207688
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 7.602996691484666
# MSE = 95.21423425669012
# R^2 = 0.6481031416890604
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 4.859196318345549
# MSE = 38.2018104061484
# R^2 = 0.8588121075734092
# New best model
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 5.018749569766344
# MSE = 40.432403120076195
# R^2 = 0.8505681871729538
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 4.446083278162194
# MSE = 31.983468049692675
# R^2 = 0.8817941244558782
# New best model
# Running experiment with learning_rate=0.0005, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 4.4306277326318435
# MSE = 35.76570395855027
# R^2 = 0.8678155744616657
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 8.694003622061226
# MSE = 125.408855576934
# R^2 = 0.5365085627541806
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 7.6862584191232814
# MSE = 91.34756585160636
# R^2 = 0.6623937409308805
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 6.495177174663852
# MSE = 74.6991279674628
# R^2 = 0.723923753044624
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 5.716452986707965
# MSE = 49.581624499355875
# R^2 = 0.8167541016583861
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 4.792983097335667
# MSE = 41.38970338968699
# R^2 = 0.84703015570144
# Running experiment with learning_rate=0.001, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 13.452379585932759
# MSE = 274.8555008045387
# R^2 = -0.01582277038373725
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 6.304427551343603
# MSE = 67.90997625892204
# R^2 = 0.7490153916581432
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 5.953582382202149
# MSE = 60.12929595174961
# R^2 = 0.7777715642723593
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 4.4455782339719505
# MSE = 33.80767212384474
# R^2 = 0.8750521526527807
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 4.641645757064079
# MSE = 36.81621335361587
# R^2 = 0.8639330566991102
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 3.7540331389294472
# MSE = 24.998583283188367
# R^2 = 0.907609161715647
# New best model
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 4.260221513791377
# MSE = 33.98451519419351
# R^2 = 0.8743985684344586
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 5.481037327911476
# MSE = 49.54923162248166
# R^2 = 0.8168738206446562
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 5.1342040462555625
# MSE = 43.735126440305564
# R^2 = 0.8383618404083961
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 4.579513276356324
# MSE = 34.857946143353615
# R^2 = 0.8711705048013219
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 4.318190777355799
# MSE = 35.90362559976133
# R^2 = 0.8673058377336003
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 4.788085925154701
# MSE = 43.02493895731261
# R^2 = 0.8409865818247186
# Running experiment with learning_rate=0.005, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 13.39889952230608
# MSE = 273.3991241389526
# R^2 = -0.010440230922720728
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 4.837444400972533
# MSE = 38.1109481718652
# R^2 = 0.8591479201232132
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 5.015079104722896
# MSE = 40.4591992593131
# R^2 = 0.8504691528501349
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 4.305794386879141
# MSE = 36.07143148324022
# R^2 = 0.8666856535388388
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 4.343362596382216
# MSE = 36.12097964318605
# R^2 = 0.8665025313202321
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 4.212726798998885
# MSE = 34.07493011910634
# R^2 = 0.8740644090698465
# Running experiment with learning_rate=0.005, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 4.088570487013141
# MSE = 31.634635768158546
# R^2 = 0.8830833537912565
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 4.822516281597051
# MSE = 40.924115901466855
# R^2 = 0.8487508939466466
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 5.356657098936803
# MSE = 45.357475672865355
# R^2 = 0.8323658924025354
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 4.416443397559008
# MSE = 36.12067844939442
# R^2 = 0.8665036444851895
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 4.254787713331698
# MSE = 33.590229646439504
# R^2 = 0.8758557859042541
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 13.41602940185942
# MSE = 273.84975867391586
# R^2 = -0.012105705400753841
# Running experiment with learning_rate=0.01, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 13.418119325113143
# MSE = 273.9070196799867
# R^2 = -0.012317333087489502
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 4.831583877612858
# MSE = 39.12216567671934
# R^2 = 0.8554106190168694
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 4.7816063180324715
# MSE = 39.1362271177068
# R^2 = 0.8553586501390494
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 3.959857810184022
# MSE = 29.412907848447478
# R^2 = 0.8912945113043264
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 4.625862589592301
# MSE = 37.36525930309166
# R^2 = 0.8619038690865942
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 3.9504362427918274
# MSE = 30.195634739924042
# R^2 = 0.8884016756251197
# Running experiment with learning_rate=0.01, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 4.2692629791309145
# MSE = 36.70989012172365
# R^2 = 0.864326010668235
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=8 and num_h_l=1
# MAE = 13.42812655995193
# MSE = 274.1880802425211
# R^2 = -0.013356088791645293
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=8 and num_h_l=2
# MAE = 13.359810490777965
# MSE = 272.4711239261817
# R^2 = -0.007010487860296122
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=16 and num_h_l=1
# MAE = 13.416927830964617
# MSE = 273.87431358556745
# R^2 = -0.012196456498357655
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=16 and num_h_l=2
# MAE = 13.422681320338574
# MSE = 274.0337356959243
# R^2 = -0.012785655584164779
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=32 and num_h_l=1
# MAE = 13.419739028288708
# MSE = 273.95173858954934
# R^2 = -0.0124826071550177
# Running experiment with learning_rate=0.1, kernel=rbf, encoding_dim=32 and num_h_l=2
# MAE = 13.422087597893281
# MSE = 274.0171103721665
# R^2 = -0.0127242109982324
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=8 and num_h_l=1
# MAE = 5.897996856047498
# MSE = 54.32483132123358
# R^2 = 0.7992239540710205
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=8 and num_h_l=2
# MAE = 7.2707475848645435
# MSE = 80.12139501596309
# R^2 = 0.7038839054925642
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=16 and num_h_l=1
# MAE = 5.557295184459501
# MSE = 50.14305776555437
# R^2 = 0.8146791324684447
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=16 and num_h_l=2
# MAE = 9.766517199667524
# MSE = 142.54403713887592
# R^2 = 0.4731796224407082
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 6.173566978232375
# MSE = 58.74030940633272
# R^2 = 0.7829050404315085
# Running experiment with learning_rate=0.1, kernel=cos, encoding_dim=32 and num_h_l=2
# MAE = 13.424959027929214
# MSE = 274.0978871989084
# R^2 = -0.013022749465476213
# Best hyper-parameters: (0.001, 'cos', 32, 1)

# %% [markdown]
# ```
# Running experiment with learning_rate=0.001, kernel=cos, encoding_dim=32 and num_h_l=1
# MAE = 3.7540331389294472
# MSE = 24.998583283188367
# R^2 = 0.907609161715647
# New best model
# ```
#
# So, an encoder does improves the performance in this case.

# %%
y_test.max(), y_test.mean(), y_test.min()
# Out:
# (81.75, 35.0368284789644, 4.57)
